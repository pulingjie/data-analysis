# %% [markdown]
# # *s a d *,**sw w **绘图学习
# ## 1.导图函数

# %%
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#year=[1950,1960,1970,1980,1990,2000,2010]
#year=list(range(1950,2020,10)) 
year=np.arange(1950,2020,10)
gdp=[300.2,543.3,1075.9,2862.5,5979.6,10289.7,14958.3]
number_p=[430,380,600,700.3,932.6,1000.34,1300.83]
plt.plot(year,gdp,label='speed',color='k',linewidth=2,linestyle='solid')
plt.plot(year,number_p,label='population',color='r',linewidth=2)

plt.legend(loc=9)

plt.plot(year,gdp,color='k',marker='o',label='speed',linewidth=2)
plt.plot(year,number_p,label='population',color='r',marker='o',linewidth=2)

plt.title("hello")
plt.ylabel("Billions of $")
plt.xlabel("year")


type(year) #类型
# Out:
# numpy.ndarray

# %%
np.arange(1950,2020,10)
# Out:
# array([1950, 1960, 1970, 1980, 1990, 2000, 2010])

# %%
plt.bar(year,gdp)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
